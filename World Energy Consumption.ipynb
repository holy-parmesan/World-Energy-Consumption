# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('World Energy Consumption.csv')
new_df = df.groupby(['country'])
new_df.last()
# Out:
#                 iso_code  year  coal_prod_change_pct  coal_prod_change_twh  \
# country
# Afghanistan          AFG  2019                24.396                 1.933
# Africa              None  2019                -2.561               -48.591
# Albania              ALB  2019              -100.000                 0.000
# Algeria              DZA  2019                 0.000                 0.065
# American Samoa       ASM  2019                   NaN                 0.000
# ...                  ...   ...                   ...                   ...
# World           OWID_WRL  2020                 1.523               698.281
# Yemen                YEM  2019                   NaN                   NaN
# Yugoslavia          None  2016                 0.000               -20.463
# Zambia               ZMB  2019                 0.000                -0.607
# Zimbabwe             ZWE  2019               -35.015                -9.422
#
# ...
